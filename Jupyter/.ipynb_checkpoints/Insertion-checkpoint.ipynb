# %%
from random import randrange
import matplotlib.pyplot as plt
import time

# %%
def insertion_sort( lista ):
  for i in range( 1, len( lista ) ):
    chave = lista[i]
    k = i
    while k > 0 and chave < lista[k - 1]:
        lista[k] = lista[k - 1]
        k -= 1
    lista[k] = chave

# %%
def num(tamanho, ordenacao):
    nums = [randrange(1000) for x in range(tamanho)]
    
    if ordenacao == 'Crescente':
        return sorted(nums)
    elif ordenacao == 'Decrescente':
        return sorted(nums, reverse=True)
    elif ordenacao == 'Desordenado':
        return nums

# %%
def graphic(variavel):
    plt.title('Messy Numbers')
    plt.grid(True)
    plt.ylabel('Numbers')
    plt.plot(variavel)
    plt.show()
    plt.clf()

# %%
var1 = num(100, 'Desordenado')
var2 = num(100, 'Crescente')
var3 = num(100, 'Decrescente')

# %%
graphic(var1)

inicio = time.time()

insertion_sort(var1)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var1)
# Out:
# Tempo: 0.0003795623779296875

# %%
graphic(var2)

inicio = time.time()

insertion_sort(var2)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var2)
# Out:
# Tempo: 6.461143493652344e-05

# %%
graphic(var3)

inicio = time.time()

insertion_sort(var3)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var3)
# Out:
# Tempo: 0.0013134479522705078

# %%
var1 = num(1000, 'Desordenado')
var2 = num(1000, 'Crescente')
var3 = num(1000, 'Decrescente')

# %%
graphic(var1)

inicio = time.time()

insertion_sort(var1)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var1)
# Out:
# Tempo: 0.05350613594055176

# %%
graphic(var2)

inicio = time.time()

insertion_sort(var2)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var2)
# Out:
# Tempo: 0.00020694732666015625

# %%
graphic(var3)

inicio = time.time()

insertion_sort(var3)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var3)
# Out:
# Tempo: 0.08555889129638672

# %%
var1 = num(10000, 'Desordenado')
var2 = num(10000, 'Crescente')
var3 = num(10000, 'Decrescente')

# %%
graphic(var1)

inicio = time.time()

insertion_sort(var1)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var1)
# Out:
# Tempo: 4.745678186416626

# %%
graphic(var2)

inicio = time.time()

insertion_sort(var2)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var2)
# Out:
# Tempo: 0.0016803741455078125

# %%
graphic(var3)

inicio = time.time()

insertion_sort(var3)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var3)
# Out:
# Tempo: 9.326776027679443

# %%
var1 = num(100000, 'Desordenado')
var2 = num(100000, 'Crescente')
var3 = num(100000, 'Decrescente')

# %%
graphic(var1)

inicio = time.time()

insertion_sort(var1)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var1)
# Out:
# Tempo: 497.9390149116516

# %%
graphic(var2)

inicio = time.time()

insertion_sort(var2)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var2)
# Out:
# Tempo: 0.0397188663482666

# %%
graphic(var3)

inicio = time.time()

insertion_sort(var3)

fim = time.time()

print('Tempo:' ,(fim - inicio))

graphic(var3)
# Out:
# Tempo: 1116.7629969120026

# %%
var1 = num(1000000, 'Desordenado')
var2 = num(1000000, 'Crescente')
var3 = num(1000000, 'Decrescente')
